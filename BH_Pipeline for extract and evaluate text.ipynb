# %% [markdown]
# # Pipeline for extract and evaluate text
#
# ###[Banafsheh Hassani](https://www.linkedin.com/in/banafsheh-hassani-7b063a129/)
#
# ###[More Projects](https://github.com/BanafshehHassani)

# %% [markdown]
# #Data : sklearn.datasets.fetch_20newsgroups
#
# * 20 newsgroups dataset is automaticaly download, catch and reuse for document classification.
# * Automaticaly get 20 categories or user can giving category name to dataset for adjusting number of them.

# %% [markdown]
# [Reference](https://scikit-learn.org/stable/auto_examples/model_selection/grid_search_text_feature_extraction.html)

# %%
# %matplotlib inline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pprint import pprint
from time import time
import logging
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(__doc__)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Built-in functions, exceptions, and other objects.
#
# Noteworthy: None is the `nil&#39; object; Ellipsis represents `...&#39; in slices.
# </div>

# %% [markdown]
# #Illustrate progress logs on stdout

# %%
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(levelname)s %(message)s')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-03-10 02:13:43,681 INFO Received command c on object id p0
# 2021-03-10 02:13:43,682 INFO Received command c on object id p0
# 2021-03-10 02:13:43,682 INFO Received command c on object id p0
# 2021-03-10 02:13:43,683 INFO Received command c on object id p0
# </div>

# %% [markdown]
# #Load couple of categories from training set

# %%
categories = [
    'alt.atheism',
    'talk.religion.misc',
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-03-10 02:13:43,715 INFO Received command c on object id p0
# 2021-03-10 02:13:43,715 INFO Received command c on object id p0
# 2021-03-10 02:13:43,716 INFO Received command c on object id p0
# 2021-03-10 02:13:43,716 INFO Received command c on object id p0
# </div>

# %% [markdown]
# #Analysis categories

# %%
categories = None
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-03-10 02:13:43,749 INFO Received command c on object id p0
# 2021-03-10 02:13:43,750 INFO Received command c on object id p0
# 2021-03-10 02:13:43,750 INFO Received command c on object id p0
# 2021-03-10 02:13:43,750 INFO Received command c on object id p0
# </div>

# %%
print("Loading 20 newsgroups dataset for categories:")
print(categories)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Loading 20 newsgroups dataset for categories:
# None
# 2021-03-10 02:13:43,789 INFO Received command c on object id p0
# 2021-03-10 02:13:43,789 INFO Received command c on object id p0
# 2021-03-10 02:13:43,789 INFO Received command c on object id p0
# 2021-03-10 02:13:43,790 INFO Received command c on object id p0
# </div>

# %%
data = fetch_20newsgroups(subset='train', categories=categories)
print("%d documents" % len(data.filenames))
print("%d categories" % len(data.target_names))
print()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">11314 documents
# 20 categories
#
# 2021-03-10 02:13:44,141 INFO Received command c on object id p0
# 2021-03-10 02:13:44,141 INFO Received command c on object id p0
# 2021-03-10 02:13:44,142 INFO Received command c on object id p0
# 2021-03-10 02:13:44,142 INFO Received command c on object id p0
# </div>

# %% [markdown]
# #Create pipeline combining the text feature extractor with the classifier

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', SGDClassifier()),
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-03-10 02:13:44,179 INFO Received command c on object id p0
# 2021-03-10 02:13:44,179 INFO Received command c on object id p0
# 2021-03-10 02:13:44,180 INFO Received command c on object id p0
# 2021-03-10 02:13:44,180 INFO Received command c on object id p0
# </div>

# %% [markdown]
# #Try more parameters to give better exploring power

# %%
parameters = {
    'vect__max_df': (0.5, 0.75, 1.0),
    # 'vect__max_features': (None, 5000, 10000, 50000),
    'vect__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams
    # 'tfidf__use_idf': (True, False),
    # 'tfidf__norm': ('l1', 'l2'),
    'clf__max_iter': (20,),
    'clf__alpha': (0.00001, 0.000001),
    'clf__penalty': ('l2', 'elasticnet'),
    # 'clf__max_iter': (10, 50, 80),
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021-03-10 02:13:44,227 INFO Received command c on object id p0
# 2021-03-10 02:13:44,227 INFO Received command c on object id p0
# 2021-03-10 02:13:44,228 INFO Received command c on object id p0
# 2021-03-10 02:13:44,228 INFO Received command c on object id p0
# </div>

# %% [markdown]
# #Find best parameters for the feature extraction and the classifier

# %%
if __name__ == "__main__":

    grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1, verbose=1)

    print("Performing grid search...")
    print("pipeline:", [name for name, _ in pipeline.steps])
    print("parameters:")
    pprint(parameters)
    t0 = time()
    grid_search.fit(data.data, data.target)
    print("done in %0.3fs" % (time() - t0))
    print()

    print("Best score: %0.3f" % grid_search.best_score_)
    print("Best parameters set:")
    best_parameters = grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Performing grid search...
# pipeline: [&#39;vect&#39;, &#39;tfidf&#39;, &#39;clf&#39;]
# parameters:
# {&#39;clf__alpha&#39;: (1e-05, 1e-06),
#  &#39;clf__max_iter&#39;: (20,),
#  &#39;clf__penalty&#39;: (&#39;l2&#39;, &#39;elasticnet&#39;),
#  &#39;vect__max_df&#39;: (0.5, 0.75, 1.0),
#  &#39;vect__ngram_range&#39;: ((1, 1), (1, 2))}
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# 2021-03-10 02:13:45,279 INFO Received command c on object id p0
# 2021-03-10 02:13:45,280 INFO Received command c on object id p0
# 2021-03-10 02:13:45,295 INFO Received command c on object id p0
# 2021-03-10 02:13:45,296 INFO Received command c on object id p0
# 2021-03-10 02:13:45,303 INFO Received command c on object id p0
# 2021-03-10 02:13:45,330 INFO Received command c on object id p0
# 2021-03-10 02:13:45,331 INFO Received command c on object id p0
# 2021-03-10 02:13:45,333 INFO Received command c on object id p0
# 2021-03-10 02:13:45,373 INFO Received command c on object id p0
# 2021-03-10 02:13:45,473 INFO Received command c on object id p0
# 2021-03-10 02:13:45,574 INFO Received command c on object id p0
# 2021-03-10 02:13:45,672 INFO Received command c on object id p0
# 2021-03-10 02:13:45,674 INFO Received command c on object id p0
# 2021-03-10 02:13:45,675 INFO Received command c on object id p0
# 2021-03-10 02:13:45,676 INFO Received command c on object id p0
# 2021-03-10 02:13:45,676 INFO Received command c on object id p0
# 2021-03-10 02:13:45,676 INFO Received command c on object id p0
# 2021-03-10 02:13:45,677 INFO Received command c on object id p0
# 2021-03-10 02:13:45,677 INFO Received command c on object id p0
# 2021-03-10 02:13:45,678 INFO Received command c on object id p0
# 2021-03-10 02:13:45,779 INFO Received command c on object id p0
# 2021-03-10 02:13:45,879 INFO Received command c on object id p0
# 2021-03-10 02:13:45,980 INFO Received command c on object id p0
# 2021-03-10 02:13:46,081 INFO Received command c on object id p0
# 2021-03-10 02:13:46,173 INFO Received command c on object id p0
# 2021-03-10 02:13:46,174 INFO Received command c on object id p0
# 2021-03-10 02:13:46,174 INFO Received command c on object id p0
# 2021-03-10 02:13:46,177 INFO Received command c on object id p0
# 2021-03-10 02:13:46,177 INFO Received command c on object id p0
# 2021-03-10 02:13:46,178 INFO Received command c on object id p0
# 2021-03-10 02:13:46,178 INFO Received command c on object id p0
# 2021-03-10 02:13:46,178 INFO Received command c on object id p0
# 2021-03-10 02:13:46,181 INFO Received command c on object id p0
# 2021-03-10 02:13:46,282 INFO Received command c on object id p0
# 2021-03-10 02:13:46,383 INFO Received command c on object id p0
# 2021-03-10 02:13:46,483 INFO Received command c on object id p0
# 2021-03-10 02:13:46,584 INFO Received command c on object id p0
# 2021-03-10 02:13:46,674 INFO Received command c on object id p0
# 2021-03-10 02:13:46,675 INFO Received command c on object id p0
# 2021-03-10 02:13:46,677 INFO Received command c on object id p0
# 2021-03-10 02:13:46,678 INFO Received command c on object id p0
# 2021-03-10 02:13:46,679 INFO Received command c on object id p0
# 2021-03-10 02:13:46,679 INFO Received command c on object id p0
# 2021-03-10 02:13:46,679 INFO Received command c on object id p0
# 2021-03-10 02:13:46,680 INFO Received command c on object id p0
# 2021-03-10 02:13:46,685 INFO Received command c on object id p0
# 2021-03-10 02:13:46,786 INFO Received command c on object id p0
# 2021-03-10 02:13:46,886 INFO Received command c on object id p0
# 2021-03-10 02:13:46,987 INFO Received command c on object id p0
# 2021-03-10 02:13:47,088 INFO Received command c on object id p0
# 2021-03-10 02:13:47,174 INFO Received command c on object id p0
# 2021-03-10 02:13:47,176 INFO Received command c on object id p0
# 2021-03-10 02:13:47,177 INFO Received command c on object id p0
# 2021-03-10 02:13:47,178 INFO Received command c on object id p0
# 2021-03-10 02:13:47,179 INFO Received command c on object id p0
# 2021-03-10 02:13:47,179 INFO Received command c on object id p0
# 2021-03-10 02:13:47,179 INFO Received command c on object id p0
# 2021-03-10 02:13:47,180 INFO Received command c on object id p0
# 2021-03-10 02:13:47,188 INFO Received command c on object id p0
# 2021-03-10 02:13:47,289 INFO Received command c on object id p0
# 2021-03-10 02:13:47,390 INFO Received command c on object id p0
# 2021-03-10 02:13:47,491 INFO Received command c on object id p0
# 2021-03-10 02:13:47,592 INFO Received command c on object id p0
# 2021-03-10 02:13:47,678 INFO Received command c on object id p0
# 2021-03-10 02:13:47,679 INFO Received command c on object id p0
# 2021-03-10 02:13:47,680 INFO Received command c on object id p0
# 2021-03-10 02:13:47,681 INFO Received command c on object id p0
# 2021-03-10 02:13:47,682 INFO Received command c on object id p0
# 2021-03-10 02:13:47,682 INFO Received command c on object id p0
# 2021-03-10 02:13:47,683 INFO Received command c on object id p0
# 2021-03-10 02:13:47,683 INFO Received command c on object id p0
# 2021-03-10 02:13:47,692 INFO Received command c on object id p0
# 2021-03-10 02:13:47,793 INFO Received command c on object id p0
# 2021-03-10 02:13:47,894 INFO Received command c on object id p0
# 2021-03-10 02:13:47,995 INFO Received command c on object id p0
# 2021-03-10 02:13:48,096 INFO Received command c on object id p0
# 2021-03-10 02:13:48,179 INFO Received command c on object id p0
# 2021-03-10 02:13:48,179 INFO Received command c on object id p0
# 2021-03-10 02:13:48,180 INFO Received command c on object id p0
# 2021-03-10 02:13:48,182 INFO Received command c on object id p0
# 2021-03-10 02:13:48,183 INFO Received command c on object id p0
# 2021-03-10 02:13:48,183 INFO Received command c on object id p0
# 2021-03-10 02:13:48,183 INFO Received command c on object id p0
# 2021-03-10 02:13:48,184 INFO Received command c on object id p0
# 2021-03-10 02:13:48,197 INFO Received command c on object id p0
# 2021-03-10 02:13:48,298 INFO Received command c on object id p0
# 2021-03-10 02:13:48,398 INFO Received command c on object id p0
# 2021-03-10 02:13:48,499 INFO Received command c on object id p0
# 2021-03-10 02:13:48,600 INFO Received command c on object id p0
# 2021-03-10 02:13:48,680 INFO Received command c on object id p0
# 2021-03-10 02:13:48,681 INFO Received command c on object id p0
# 2021-03-10 02:13:48,682 INFO Received command c on object id p0
# 2021-03-10 02:13:48,683 INFO Received command c on object id p0
# 2021-03-10 02:13:48,684 INFO Received command c on object id p0
# 2021-03-10 02:13:48,684 INFO Received command c on object id p0
# 2021-03-10 02:13:48,684 INFO Received command c on object id p0
# 2021-03-10 02:13:48,685 INFO Received command c on object id p0
# 2021-03-10 02:13:48,700 INFO Received command c on object id p0
# 2021-03-10 02:13:48,801 INFO Received command c on object id p0
# 2021-03-10 02:13:48,902 INFO Received command c on object id p0
# 2021-03-10 02:13:49,003 INFO Received command c on object id p0
# 2021-03-10 02:13:49,106 INFO Received command c on object id p0
# 2021-03-10 02:13:49,183 INFO Received command c on object id p0
# 2021-03-10 02:13:49,186 INFO Received command c on object id p0
# 2021-03-10 02:13:49,186 INFO Received command c on object id p0
# 2021-03-10 02:13:49,188 INFO Received command c on object id p0
# 2021-03-10 02:13:49,188 INFO Received command c on object id p0
# 2021-03-10 02:13:49,188 INFO Received command c on object id p0
# 2021-03-10 02:13:49,188 INFO Received command c on object id p0
# 2021-03-10 02:13:49,189 INFO Received command c on object id p0
# 2021-03-10 02:13:49,206 INFO Received command c on object id p0
# 2021-03-10 02:13:49,307 INFO Received command c on object id p0
# 2021-03-10 02:13:49,408 INFO Received comma
